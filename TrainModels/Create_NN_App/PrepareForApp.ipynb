# %%
# !pip3 install torch==1.13.0 torchvision torchaudio torchtext

# %%
from google.colab import drive
drive.mount('/content/drive')
import torchvision
import torch.optim as optim
from torchvision import datasets, models, transforms
from torch.utils.mobile_optimizer import optimize_for_mobile
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
# Out:
# Mounted at /content/drive

# %%
print(torch.__version__)
print(torchvision.__version__)
# Out:
# 1.13.0+cu117
# 0.14.0+cu117

# %%
temp_model = modelArchs.get_MobileNetSa(6,False)

app_model_meta = modelArchs.get_metaModel_MobileNets(temp_model,27,6, metaModelType = 1)
app_model_meta.load_state_dict(torch.load('drive/MyDrive/final_model_metadata.pt', map_location=torch.device("cpu"))['model'])
app_model_meta.eval()

traced_script_module = torch.jit.trace(app_model_meta, (torch.rand(1,27), torch.rand(1,3,224,224)))

traced_script_module._save_for_lite_interpreter("drive/MyDrive/final_app_network.ptl")
